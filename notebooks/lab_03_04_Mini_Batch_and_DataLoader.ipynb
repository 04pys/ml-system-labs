# %% [markdown]
# <a href="https://colab.research.google.com/github/04pys/ml-system-labs/blob/main/notebooks/lab_03_04_Mini_Batch_and_DataLoader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 미니 배치 학습을 위해서는 dataset, dataloader가 필요하다.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋 - 텐서를 입력으로 받아서 dataset으로 변환해준다
from torch.utils.data import DataLoader # 데이터로더

# %%
x_train  =  torch.FloatTensor([[73,  80,  75],
                               [93,  88,  93],
                               [89,  91,  90],
                               [96,  98,  100],
                               [73,  66,  70]])
y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
dataset = TensorDataset(x_train, y_train)

# %%
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

# %%
model = nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    print(batch_idx)
    print(samples)
    x_train, y_train = samples

    #H(x), 즉 hypothesis 계산
    prediction = model(x_train)

    #cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    0/20 Batch 1/3 Cost: 50806.765625
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    0/20 Batch 2/3 Cost: 13019.888672
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    0/20 Batch 3/3 Cost: 5576.521484
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    1/20 Batch 1/3 Cost: 1058.833008
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch    1/20 Batch 2/3 Cost: 727.479492
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    1/20 Batch 3/3 Cost: 138.880203
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    2/20 Batch 1/3 Cost: 49.033897
# 1
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
# ...

# %%
#위에껀 samples가 어떻게 나오는지 확인함. 매번 epoch마다 가져오는 순서가 달라짐(shuffle=True)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples

    #H(x), 즉 hypothesis 계산
    prediction = model(x_train)

    #cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 61622.687500
# Epoch    0/20 Batch 2/3 Cost: 18713.376953
# Epoch    0/20 Batch 3/3 Cost: 8046.379395
# Epoch    1/20 Batch 1/3 Cost: 1671.010498
# Epoch    1/20 Batch 2/3 Cost: 456.534149
# Epoch    1/20 Batch 3/3 Cost: 247.423645
# Epoch    2/20 Batch 1/3 Cost: 34.784378
# Epoch    2/20 Batch 2/3 Cost: 21.014734
# Epoch    2/20 Batch 3/3 Cost: 1.305729
# Epoch    3/20 Batch 1/3 Cost: 4.370938
# Epoch    3/20 Batch 2/3 Cost: 2.113569
# Epoch    3/20 Batch 3/3 Cost: 0.573147
# Epoch    4/20 Batch 1/3 Cost: 2.779220
# Epoch    4/20 Batch 2/3 Cost: 0.217589
# Epoch    4/20 Batch 3/3 Cost: 3.315982
# Epoch    5/20 Batch 1/3 Cost: 1.216295
# Epoch    5/20 Batch 2/3 Cost: 2.821357
# Epoch    5/20 Batch 3/3 Cost: 2.845082
# Epoch    6/20 Batch 1/3 Cost: 2.185885
# Epoch    6/20 Batch 2/3 Cost: 0.900499
# Epoch    6/20 Batch 3/3 Cost: 3.161067
# Epoch    7/20 Batch 1/3 Cost: 1.532592
# Epoch    7/20 Batch 2/3 Cost: 3.045082
# ...

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]])
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[152.4505]], grad_fn=<AddmmBackward0>)

# %%
#커스텀 dataset을 만들수 있다 (torch.utils.data.Dataset을 상속받음)

# %%
#class CustumDataset(torch.utils.data.Dataset):
  #def __init__(self):
    #데이터셋의 전처리를 해주는 부분

  #def __len__(self):
    #데이터셋의 길이. 즉, 총 샘플의 수를 적어주는 부분

  #def __getitem__(self, idx):
    #데이터셋에서 특정 1개의 샘플을 가져오는 함수

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
#Dataset 상속
class CustomDataset(torch.utils.data.Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  #총 데이터 개수를 리턴
  def __len__(self):
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor의 형태로 출력
  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x,y

# %%
#x_data는 입력 데이터이고, y_data는 해당 입력에 대응하는 출력 데이터
# 클래스가 초기화될 때 x_data와 y_data를 내부 데이터로 저장
#총 데이터 개수를 리턴하는 메서드도 있고, 인덱스를 입력으로 받아 인덱스에 맵핑된 입출력 데이터를 출력하는 메서드도 있음

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size = 2, shuffle = True)

# %%
model = nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 44966.265625
# Epoch    0/20 Batch 2/3 Cost: 10731.435547
# Epoch    0/20 Batch 3/3 Cost: 2078.650879
# Epoch    1/20 Batch 1/3 Cost: 1459.360352
# Epoch    1/20 Batch 2/3 Cost: 532.810791
# Epoch    1/20 Batch 3/3 Cost: 99.628029
# Epoch    2/20 Batch 1/3 Cost: 46.307335
# Epoch    2/20 Batch 2/3 Cost: 17.232510
# Epoch    2/20 Batch 3/3 Cost: 11.189748
# Epoch    3/20 Batch 1/3 Cost: 1.449075
# Epoch    3/20 Batch 2/3 Cost: 0.190758
# Epoch    3/20 Batch 3/3 Cost: 1.691040
# Epoch    4/20 Batch 1/3 Cost: 0.728271
# Epoch    4/20 Batch 2/3 Cost: 0.323160
# Epoch    4/20 Batch 3/3 Cost: 0.650497
# Epoch    5/20 Batch 1/3 Cost: 0.478083
# Epoch    5/20 Batch 2/3 Cost: 0.746783
# Epoch    5/20 Batch 3/3 Cost: 0.454538
# Epoch    6/20 Batch 1/3 Cost: 0.858568
# Epoch    6/20 Batch 2/3 Cost: 0.392252
# Epoch    6/20 Batch 3/3 Cost: 0.500994
# Epoch    7/20 Batch 1/3 Cost: 0.271228
# Epoch    7/20 Batch 2/3 Cost: 0.678507
# ...

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]])
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[152.0375]], grad_fn=<AddmmBackward0>)
